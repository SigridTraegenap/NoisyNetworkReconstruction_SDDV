# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d221beb0603c> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 import numpy as np
#       3 from mpl_toolkits import mplot3d
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#take from other code:
resvec=np.linspace(0.001,10,10)

# %% [markdown]
# # res/dt plot

# %%
A1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M2000_N30_T1_res0.001.dat")
A2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M2_N30_T1_res1.1119999999999999.dat")
A3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res2.223.dat")
A4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res3.334.dat")
A5=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res4.445.dat")
A6=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res5.556.dat")
A7=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res6.667000000000001.dat")
A8=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res7.7780000000000005.dat")
A9=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res8.889.dat")
A10=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/ratioResDt/AUC_c1_initalconditionsrandom state_betarandom_M1_N30_T1_res10.0.dat")

# %%
print(A1.shape)
# Out:
# (3, 80)

# %%
A=np.zeros((10,80))

# %%
vecA=(A1[1,:],A2[1,:],A3[1,:],A4[1,:],A5[1,:],A6[1,:],A7[1,:],A8[1,:],A9[1,:],A10[1,:])

# %%
counter = -1
for i in vecA:
    counter = counter + 1
    A[counter,:]=i

# %%
#noise
noise=A1[0,:]
dn=noise[-1]/(np.size(noise)-1)
#ratio res/dt
ratio=0.001/resvec
dr=(ratio[-1]-ratio[0])/(np.size(resvec)-1)

# %%
print(ratio)
# Out:
# [  1.00000000e+00   8.99280576e-04   4.49842555e-04   2.99940012e-04
#    2.24971879e-04   1.79985601e-04   1.49992500e-04   1.28567755e-04
#    1.12498594e-04   1.00000000e-04]

# %%
# Make a 3d plot

# make grid for plotting
np, rp = np.meshgrid(noise, ratio)

# make figure
fig = plt.figure()
ax = plt.axes(projection='3d')

ax.plot_surface(np, rp, A, rstride=10, cstride=10, cmap='viridis')
ax.view_init(elev=50., azim=40.)
ax.set_ylabel('dt/res') 
ax.set_xlabel('noise')
ax.set_zlabel('AUC')
plt.show()
