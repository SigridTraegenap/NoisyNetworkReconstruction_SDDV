# %%
from sklearn import metrics
import numpy as np
import pylab as plt
import _pickle as pickle
import scipy.io
import os
from StablePower3 import simulate
from StablePower3 import topology
from StablePower3 import beta
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-d194b56d3060> in <module>
# ----> 1 from sklearn import metrics
#       2 import numpy as np
#       3 import pylab as plt
#       4 import _pickle as pickle
#       5 import scipy.io
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
#number of nodes N
N=10
#seconds for each time series simulation
T=20
#number of time series
M=1000

# %%
J=topology(N,5)
d=beta(N)

# %%
 np.savetxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/4.Treffen/cubicSimulDifferentNoiseLevel/connectivitySOR.dat",J,delimiter="\t",fmt="%1.4f")

# %%
Numb=11
sigma=np.linspace(-5,5,Numb)
sigma=10**sigma
#for saving stuff
cond='steady state' #one of the two initial conditions
#cond='random state'
b='one'
#setting simulation parameters

for i in range(len(sigma)):
    simulate(N,M,sigma[i],T,J,d)
    data=np.around(pickle.load( open("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/data.p", "rb" ) ),4)#around rounds the datapoints to 4 signifitcant 
    pickle.dump(data,open("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/4.Treffen/cubicSimulDifferentNoiseLevel/Data/data_%s.p"%(sigma[i]),"wb"))
    print ("Simulations completed for sigma:",sigma[i])
    
    #np.savetxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/4.Treffen/cubicSimulDifferentNoiseLevel/Data/Cubic_initalconditions{}_beta{}_M{}_N{}_T{}_noise{}.dat".format(cond,b,M,N,T,i),data,delimiter="\t",fmt="%1.4f")
# Out:
# Simulating:
# Time series: 1/20
# Time series: 2/20
# Time series: 3/20
# Time series: 4/20
# Time series: 5/20
# Time series: 6/20
# Time series: 7/20
# Time series: 8/20
# Time series: 9/20
# Time series: 10/20
# Time series: 11/20
# Time series: 12/20
# Time series: 13/20
# Time series: 14/20
# Time series: 15/20
# Time series: 16/20
# Time series: 17/20
# Time series: 18/20
# Time series: 19/20
# Time series: 20/20
# Simulations completed.
# Outputs saved to:
#  'Data/data.p' (Pickled data)
#  'Data/connectivity.dat' (Numpy array)
# Simulations completed for sigma: 1e-05
# Simulating:
# Time series: 1/20
# Time series: 2/20
# Time series: 3/20
# Time series: 4/20
# Time series: 5/20
# Time series: 6/20
# Time series: 7/20
# Time series: 8/20
# Time series: 9/20
# Time series: 10/20
# Time series: 11/20
# Time series: 12/20
# Time series: 13/20
# Time series: 14/20
# Time series: 15/20
# Time series: 16/20
# Time series: 17/20
# Time series: 18/20
# Time series: 19/20
# ...
