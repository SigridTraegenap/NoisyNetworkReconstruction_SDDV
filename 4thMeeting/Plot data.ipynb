# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # CUBIC CASE AUC

# %% [markdown]
# ## random initial conditions

# %%
A1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betadegradation random_M1000_M30_T1.dat")
A2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betadegradation random_M1000_N30_T1_random[ 0.19505153].dat")
A3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.14851579].dat")
A4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.82082571].dat")

# %% [markdown]
# ## initial condition is steady state

# %%
B1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionssteady state_betadegradation random_M1000_M30_T1.dat")
B2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.02169486].dat")
B3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.6663414].dat")
B4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.85011529].dat")

# %%
plt.plot(A1[0,:],A1[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(A2[0,:],A2[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(A3[0,:],A3[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(A4[0,:],A4[1,:],color="red",marker='o',label='random initial conditions')
plt.xscale('log')
plt.legend()
plt.show()
plt.plot(B1[0,:],B1[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(B2[0,:],B2[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(B3[0,:],B3[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(B4[0,:],B4[1,:],color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %%
#plt.savefig('Vergleich.pdf') #evtl to save plots

# %%
A=A1[1,:]+A2[1,:]+A3[1,:]+A4[1,:]
A=A/4
B=B1[1,:]+B2[1,:]+B3[1,:]+B4[1,:]
B=B/4

# %%
plt.plot(A1[0,:],A,color="red",marker='o',label='random initial conditions')
plt.plot(B1[0,:],B,color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.plot(A1[0,:],A,color="red",marker='o',label='random initial conditions')
plt.plot(B1[0,:],B,color="blue",marker='o',label='initial steady state')
plt.xscale('log')
#plt.xlim(0,2)
plt.ylim(0.625,0.7)
plt.legend()
plt.show()

# %%
plt.plot(A1[0,:],A1[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(A2[0,:],A2[1,:],color="red",marker='o')
plt.plot(A3[0,:],A3[1,:],color="red",marker='o',)
plt.plot(A4[0,:],A4[1,:],color="red",marker='o')
plt.xscale('log')
plt.title('Reconstructability dependend on the noise strength')
plt.xlabel('log(noise)')
plt.ylabel('AUC')
plt.legend()
plt.savefig('Reconstructability3case',format='png',dpi=600)
#plt.show()

# %% [markdown]
# # LINEAR CASE AUC

# %% [markdown]
# ## random initial conditions

# %%
C1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.07437047].dat")
C2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.16889738].dat")
C3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.43642472].dat")
C4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.53163958].dat")

# %% [markdown]
# ## initial condition is steady state

# %%
D1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.00380562].dat")
D2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.2540565].dat")
D3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.51118803].dat")
D4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c1_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.68430949].dat")

# %%
plt.plot(C1[0,:],C1[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C2[0,:],C2[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C3[0,:],C3[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C4[0,:],C4[1,:],color="red",marker='o',label='random initial conditions')
plt.xscale('log')
plt.legend()
plt.show()
plt.plot(D1[0,:],D1[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(D2[0,:],D2[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(D3[0,:],D3[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(D4[0,:],D4[1,:],color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.plot(C1[0,:],C1[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C2[0,:],C2[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C3[0,:],C3[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(C4[0,:],C4[1,:],color="red",marker='o',label='random initial conditions')
plt.xscale('log')
plt.title('Reconstructability dependend on the noise strength')
plt.legend()
plt.show()

# %%
C=C1[1,:]+C2[1,:]+C3[1,:]+C4[1,:]
C=C/4
D=D1[1,:]+D2[1,:]+D3[1,:]+D4[1,:]
D=D/4

# %%
plt.plot(C1[0,:],C,color="red",marker='o',label='random initial conditions')
plt.plot(D1[0,:],D,color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.plot(C1[0,:],C,color="red",marker='o',label='random initial conditions')
plt.plot(D1[0,:],D,color="blue",marker='o',label='initial steady state')
plt.xscale('log')
#plt.xlim(0,0.25)
plt.ylim(0.625,0.7)
plt.legend()
plt.show()

# %% [markdown]
# # 5th power case AUC

# %% [markdown]
# ## random initial conditions

# %%
E1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.09178866].dat")
E2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.40814351].dat")
E3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.71125631].dat")
E4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.74042239].dat")

# %% [markdown]
# ## initial condition is steady state

# %%
F1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.12585629].dat")
F2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.78805268].dat")
F3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.89586993].dat")
F4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c5_initalconditionssteady state_betarandom_M1000_N30_T1_random[ 0.95517605].dat")

# %%
plt.plot(E1[0,:],E1[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(E2[0,:],E2[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(E3[0,:],E3[1,:],color="red",marker='o',label='random initial conditions')
plt.plot(E4[0,:],E4[1,:],color="red",marker='o',label='random initial conditions')
plt.xscale('log')
plt.legend()
plt.show()
plt.plot(F1[0,:],F1[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(F2[0,:],F2[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(F3[0,:],F3[1,:],color="blue",marker='o',label='initial steady state')
plt.plot(F4[0,:],F4[1,:],color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %%
E=E1[1,:]+E2[1,:]+E3[1,:]+E4[1,:]
E=E/4
F=F1[1,:]+F2[1,:]+F3[1,:]+F4[1,:]
F=F/4

# %%
plt.plot(E1[0,:],E,color="red",marker='o',label='random initial conditions')
plt.plot(F1[0,:],F,color="blue",marker='o',label='initial steady state')
plt.xscale('log')
plt.legend()
plt.show()

# %% [markdown]
# # Simulating cubic case with noise

# %%
G1=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.65444272].dat")
G2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.97379465].dat")
G3=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.57244619].dat")
G4=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionsrandom state_betarandom_M1000_N30_T1_random[ 0.86675788].dat")
#G2=np.loadtxt("/home/beate/Dokumente/00. UNI/0.Stipendium/Kolleg/network_reconstruction/3.Treffen/Data/AUCvalues/AUC_c3_initalconditionssteady state_betadegradation random_M1000_M30_T1.dat")

# %%
G=G1[1,:]+G2[1,:]+G3[1,:]+G4[1,:]
G=G/4

# %%
plt.plot(B1[0,:],G,color="red",marker='o',label='fake cubic case, averaged')
plt.plot(B1[0,:],B,color="blue",marker='o',label='true cubic case, averaged')
#plt.plot(G3[0,:],G3[1,:],color="red",marker='o',label='random initial conditions')
#plt.plot(G4[0,:],G4[1,:],color="red",marker='o',label='random initial conditions')
plt.xscale('log')
plt.legend()
plt.show()
#both begun in steady state

# %% [markdown]
# for the blue line I simply changed the cubic term in the model to a noise sigma^4 to see if it behaves similar
#
# it does behave similar
