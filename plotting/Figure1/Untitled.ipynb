# %%
from os.path import abspath, sep, pardir
import sys
sys.path.append(abspath('') + sep + pardir + sep )
import MPL_style

# %%
def find(s, ch):
    return [i for i, ltr in enumerate(s) if ltr == ch]
pwd_p=abspath('')
idxs=find(pwd_p, sep)
path_GIT=pwd_p[:idxs[-2]] + sep

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import scipy.io as sio

# %%
summary_wo_noise_2palg.mat
summary_2palg_precisionaddnoise_S1e-01.mat
summary_2palg_precisionround_S1e-01.mat
summary_2palg_precisionfull_S1e-01.mat
summary_w_noise_2palg.mat

# %%
A=sio.loadmat(path_GIT+"proof_of_concept/strawman wo noise/simulations/summary_wo_noise_2palg.mat")

# %%
/Users/straegenap/Documents/Natwiss_Kolleg/NoisyNetworkReconstruction_SDDV/proof_of_concept/strawman_wo_noise/simulations/summary wo noise_2palg.mat

# %%
/Users/straegenap/Documents/Natwiss_Kolleg/NoisyNetworkReconstruction_SDDV/proof_of_concept/strawman wo noise/simulations/summary_wo_noise_2palg.mat
# Out:
# '/Users/straegenap/Documents/Natwiss_Kolleg/NoisyNetworkReconstruction_SDDV/'

# %%
A
# Out:
# {'__globals__': [],
#  '__header__': 'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Thu Sep 26 16:42:23 2019',
#  '__version__': '1.0',
#  'all_AUCS': array([[0.51783877],
#         [0.49933511],
#         [0.53300208],
#         [0.53950217],
#         [0.50716271],
#         [0.51821269],
#         [0.5341446 ],
#         [0.49469508],
#         [0.51707004],
#         [0.53764786],
#         [0.52877831],
#         [0.49403183],
#         [0.52897008],
#         [0.46563142],
#         [0.55141292],
#         [0.54369491],
#         [0.5315123 ],
#         [0.56518658],
#         [0.5330876 ],
#         [0.51220886],
#         [0.48911486],
#         [0.50304385],
#         [0.50444314],
#         [0.48738236],
#         [0.55362654],
#         [0.53593474],
#         [0.54869378],
#         [0.53878968],
#         [0.52142909],
#         [0.49415848],
#         [0.53015879],
#         [0.56342544],
#         [0.53764861],
#         [0.5395062 ],
#         [0.5666495 ],
#         [0.53378722],
#         [0.52107216],
#         [0.52946796],
#         [0.49561839],
#         [0.51022215],
#         [0.56435092],
#         [0.55424526],
#         [0.52147451],
#         [0.54293085],
#         [0.50571382],
#         [0.52859531],
#         [0.54824368],
#         [0.47365152],
#         [0.52331156],
#         [0.51463805]]),
#  'all_dfs': array([[[ 0.        , -0.13687674, -0.36854922, ..., -0.02979576,
#            0.30741941,  1.00697805],
#          [-0.44912164,  0.        , -0.37213959, ...,  0.39008026,
#           -0.14969034,  0.39441804],
#          [-0.38201554, -0.34313356,  0.        , ...,  0.33799898,
#            0.03600923,  0.12945973],
#          ...,
#          [ 0.14037002,  0.01708132,  0.42719676, ...,  0.        ,
#            0.248877  ,  0.85575572],
#          [-0.00584319,  0.01496614,  0.1896735 , ...,  0.43439225,
#            0.        , -0.30911229],
#          [ 0.58116597, -0.07181125, -0.22204892, ...,  0.64865434,
#           -0.17685122,  0.        ]],
#
#         [[ 0.        ,  0.15590868,  0.29948778, ..., -0.06322096,
#           -0.0932899 ,  0.58550416],
#          [ 0.15981093,  0.        ,  0.028077  , ...,  0.26166194,
#           -0.7607103 ,  0.06539352],
#          [-0.05389729, -0.24468493,  0.        , ...,  0.00378051,
#           -0.01494355, -0.17474821],
#          ...,
#          [-0.40022899,  0.3591581 ,  0.12817023, ...,  0.        ,
#            1.00550387, -0.06871015],
#          [ 0.39379564, -0.41404048, -0.05175502, ...,  0.48134809,
#            0.        , -0.00208933],
#          [ 0.26307821, -0.07119971, -0.35842525, ..., -0.19062882,
#            0.32866403,  0.        ]],
#
#         [[ 0.        ,  1.08758245,  0.33501987, ..., -0.1550598 ,
#           -0.04945705,  0.05784661],
#          [ 1.28185551,  0.        ,  0.31293513, ...,  0.26233633,
#            0.40454991, -0.10361092],
#          [ 0.89439023, -0.10274605,  0.        , ..., -0.42215654,
#           -0.13286773, -0.20807848],
#          ...,
#          [ 0.22538947,  0.06174083, -0.09479015, ...,  0.        ,
#            0.28488951, -0.50713735],
#          [-0.4415851 ,  0.74218665, -0.11890525, ...,  0.09578085,
#            0.        ,  0.36010319],
#          [ 0.31507784, -0.54809418,  0.59770613, ..., -0.02155131,
#            0.63081471,  0.        ]],
#
#         ...,
#
#         [[ 0.        ,  0.11630039,  0.40917214, ..., -0.68285341,
#           -0.06014695, -0.16978824],
#          [ 0.19247745,  0.        , -0.02008688, ..., -0.51865366,
#           -0.21265148,  0.2011063 ],
#          [ 0.06432497,  0.00776669,  0.        , ...,  0.25535372,
#            0.03810263,  0.41390631],
#          ...,
#          [-0.00875257, -0.00643101,  0.17753443, ...,  0.        ,
#           -0.63753842, -0.07712535],
#          [-0.09685503, -0.07970187, -0.26126956, ..., -0.22243329,
#            0.        ,  0.14941393],
#          [ 0.04713241,  0.58131306, -0.18037298, ...,  0.45790197,
#            0.38612227,  0.        ]],
#
#         [[ 0.        , -0.25405976, -0.8109699 , ...,  0.74305082,
#           -0.3237836 , -0.33010562],
#          [-0.04458971,  0.        ,  0.55167075, ...,  0.80926631,
#           -0.68605924,  0.00604201],
#          [ 0.17643352,  0.66418977,  0.        , ..., -0.20159459,
#            1.16456211,  0.12027851],
#          ...,
#          [ 0.63507653,  0.66431586, -0.33168138, ...,  0.        ,
#            0.65067475,  0.22214921],
#          [-1.4344386 , -0.92857893,  0.97180897, ...,  0.59599954,
#            0.        , -0.03010225],
#          [-0.02607686,  0.0346693 , -0.31440607, ..., -0.42146563,
#            0.20518338,  0.        ]],
#
#         [[ 0.        , -0.27584628,  0.24301006, ..., -0.34711185,
#            0.4473873 , -0.29079873],
#          [-0.07611163,  0.        , -0.29338264, ...,  0.72289506,
#           -0.08562933, -0.09696192],
#          [ 0.02860148, -0.30433486,  0.        , ...,  0.73057528,
#            0.20593142, -0.54628406],
#          ...,
#          [ 0.08689398,  0.77642622, -0.14110163, ...,  0.        ,
#           -0.37617719,  0.39112088],
#          [-0.15120771,  0.07285226, -0.08649608, ..., -0.36851342,
#            0.        ,  0.73836871],
#          [-0.16626546, -0.04907104, -0.01244986, ...,  0.53349348,
#            0.94609105,  0.        ]]])}
